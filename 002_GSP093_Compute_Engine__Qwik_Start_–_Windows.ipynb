# %% [markdown]
# [Compute Engine: Qwik Start – Windows](https://www.cloudskillsboost.google/focuses/560?catalog_rank=%7B%22rank%22%3A16%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=23682091)

# %% [markdown]
# ![2023-05-07 18_17_27-Compute Engine_ Qwik Start – Windows _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/compute/docs/disks/

# https://cloud.google.com/compute/docs/disks/

# https://cloud.google.com/compute/docs/autoscaler/

# %% [markdown]
# ![2023-05-07 18_24_19-Compute Engine_ Qwik Start – Windows _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-07 18_25_15-Compute Engine_ Qwik Start – Windows _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-07 18_26_10-Compute Engine_ Qwik Start – Windows _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-07 18_27_13-Compute Engine_ Qwik Start – Windows _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud compute instances get-serial-port-output instance-1

# %% [markdown]
# ![2023-05-07 18_28_43-Compute Engine_ Qwik Start – Windows _ Google Cloud Skills Boost.png](data:image/png;base64,...)
